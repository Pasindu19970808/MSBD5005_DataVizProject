# %%
import pandas as pd
import numpy as np
import os

# %%
print(os.getcwd())
# Out:
# d:\GitHub\MSBD5005_DataVizProject

# %% [markdown]
# ## Apartments

# %%
pd.read_csv("./Datasets/Attributes/Apartments.csv")
# Out:
#       apartmentId  rentalCost  maxOccupancy   numberOfRooms  \
# 0               1      768.16              2              4
# 1               2     1014.55              2              1
# 2               3     1057.39              4              3
# 3               4     1259.10              4              3
# 4               5      411.50              1              4
# ...           ...         ...            ...            ...
# 1512         1729      703.80              2              4
# 1513         1730     1104.62              4              2
# 1514         1731      890.69              4              1
# 1515         1732      703.80              2              3
# 1516         1733      607.99              2              3
#
#                                            location  buildingId
# 0      POINT (1077.6979444315298 648.4427163702453)         340
# 1     POINT (-185.9292838076562 1520.3270983045118)         752
# ...

# %% [markdown]
# ## Buildings

# %%
pd.read_csv("./Datasets/Attributes/Buildings.csv")
# Out:
#       buildingId                                           location  \
# 0              1  POLYGON ((350.0638997002585 4595.665606173783,...
# 1              2  POLYGON ((-1926.972613718425 2725.610686806701...
# 2              3  POLYGON ((685.6846002015491 1552.131491805318,...
# 3              4  POLYGON ((-976.7845160060303 4542.38209636188,...
# 4              5  POLYGON ((1259.3061988755617 3572.726728111263...
# ...          ...                                                ...
# 1037        1038  POLYGON ((361.2332515102781 4376.8840047388585...
# 1038        1039  POLYGON ((1011.5463728925471 362.9701764035531...
# 1039        1040  POLYGON ((-3562.8074734172264 7362.92295511692...
# 1040        1041  POLYGON ((-4151.699758553839 5418.613349758049...
# 1041        1042  POLYGON ((-1658.924569481752 4827.536640495573...
#
#      buildingType  maxOccupancy                  units
# 0      Commercial           NaN                    NaN
# ...

# %% [markdown]
# ## Employers

# %%
pd.read_csv("./Datasets/Attributes/Employers.csv")
# Out:
#      employerId                                       location  buildingId
# 0           379  POINT (-1849.997168394888 1744.6010147106394)         823
# 1           380    POINT (41.51783767879146 418.7264799744545)         154
# 2           381   POINT (877.2786575380362 1358.5441805909259)         279
# 3           382   POINT (670.3987400004884 1584.4743462106067)           3
# 4           383   POINT (829.9556783260775 2163.4803049897623)         146
# ..          ...                                            ...         ...
# 248        1793  POINT (-3313.211912858075 6185.8337275541235)         738
# 249        1794   POINT (-3786.373075235378 4999.485452069126)         802
# 250        1795    POINT (-3267.606054814424 6452.56705940432)         953
# 251        1796   POINT (-3725.261225376805 6345.551342169127)        1011
# 252        1797   POINT (-3759.480918044369 5179.602735764589)         949
#
# [253 rows x 3 columns]

# %% [markdown]
# ## Jobs

# %%
pd.read_csv("./Datasets/Attributes/Jobs.csv")
# Out:
#       jobId  employerId  hourlyRate   startTime     endTime  \
# 0         0         379   10.000000  7:46:00 AM  3:46:00 PM
# 1         1         379   22.217633  7:31:00 AM  3:31:00 PM
# 2         2         380   10.000000  8:00:00 AM  4:00:00 PM
# 3         3         380   15.312071  7:39:00 AM  3:39:00 PM
# 4         4         381   21.355409  7:53:00 AM  3:53:00 PM
# ...     ...         ...         ...         ...         ...
# 1323   1323        1796   37.166553  7:29:00 AM  3:29:00 PM
# 1324   1324        1796   23.815211  8:14:00 AM  4:14:00 PM
# 1325   1325        1797   13.117569  7:37:00 AM  3:37:00 PM
# 1326   1326        1797   10.000000  7:31:00 AM  3:31:00 PM
# 1327   1327        1797   11.932836  8:19:00 AM  4:19:00 PM
#
#                                        daysToWork educationRequirement
# 0      [Monday,Tuesday,Wednesday,Thursday,Friday]  HighSchoolOrCollege
# 1      [Monday,Tuesday,Wednesday,Thursday,Friday]            Bachelors
# ...

# %% [markdown]
# ## Participants

# %%
pd.read_csv("./Datasets/Attributes/Participants.csv")
# Out:
#       participantId  householdSize  haveKids  age       educationLevel  \
# 0                 0              3      True   36  HighSchoolOrCollege
# 1                 1              3      True   25  HighSchoolOrCollege
# 2                 2              3      True   35  HighSchoolOrCollege
# 3                 3              3      True   21  HighSchoolOrCollege
# 4                 4              3      True   43            Bachelors
# ...             ...            ...       ...  ...                  ...
# 1006           1006              1     False   19  HighSchoolOrCollege
# 1007           1007              1     False   40  HighSchoolOrCollege
# 1008           1008              1     False   23             Graduate
# 1009           1009              1     False   39                  Low
# 1010           1010              1     False   52  HighSchoolOrCollege
#
#      interestGroup  joviality
# 0                H   0.001627
# 1                B   0.328087
# ...

# %% [markdown]
# ## Pubs

# %%
pd.read_csv("./Datasets/Attributes/Pubs.csv")
# Out:
#     pubId  hourlyCost  maxOccupancy  \
# 0     442    8.281103            64
# 1     443    6.417435            64
# 2     444   12.581806            84
# 3     892   11.642905            96
# 4     893   14.840473            79
# 5     894   12.311210            72
# 6    1342   14.140037            77
# 7    1343   10.524972            67
# 8    1344   10.415293            60
# 9    1798   11.545351            64
# 10   1799    7.487082            73
# 11   1800   10.206845            62
#
#                                          location  buildingId
# 0     POINT (964.4380231713202 3991.603473784208)         556
# 1     POINT (1809.880173357865 4339.172426035451)          29
# 2     POINT (770.4279044387976 932.5852003214752)        1012
# 3   POINT (-1524.9573211662105 3815.271490114369)         502
# 4   POINT (-1608.766411449925 3886.4924784954583)         164
# 5   POINT (-1702.5378155541193 3865.477090848479)         238
# ...

# %% [markdown]
# ## Restaurants

# %%
pd.read_csv("./Datasets/Attributes/Restaurants.csv")
# Out:
#     restaurantId  foodCost  maxOccupancy   \
# 0            445      5.15             71
# 1            446      4.17             82
# 2            447      5.87            119
# 3            448      4.07             98
# 4            449      5.11             53
# 5            895      4.44            103
# 6            896      5.86            107
# 7            897      5.76            104
# 8            898      4.22            115
# 9            899      5.65             85
# 10          1345      4.70             72
# 11          1346      5.85             74
# 12          1347      4.41             87
# 13          1348      4.23             57
# 14          1349      4.77            104
# 15          1801      5.51             64
# 16          1802      5.08             72
# 17          1803      4.35             94
# 18          1804      5.92             48
# 19          1805      5.59             85
#
#                                           location  buildingId
# ...

# %% [markdown]
# ## Schools

# %%
pd.read_csv("./Datasets/Attributes/Schools.csv")
# Out:
#    schoolId  monthlyCost  maxEnrollment  \
# 0         0    12.812445            242
# 1       450    91.143514            418
# 2       900    38.005380            394
# 3      1350    73.197852            384
#
#                                          location  buildingId
# 0   POINT (-376.7505037068263 1607.9843212558562)         662
# 1   POINT (-2597.447677094323 3194.1547530883445)         943
# 2  POINT (-2539.1584040534744 6556.0323181733565)         262
# 3    POINT (-4701.462928834322 5141.762936081409)         123
