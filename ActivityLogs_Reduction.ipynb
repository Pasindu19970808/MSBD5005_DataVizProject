# %% [markdown]
# This notebook intends to reduce the size of the activity logs.
#
# As the activity log polls every 5 minutes regardless of whether there has been any movement, we can get rid of timestamps which give no useful information.
#
# - Step 1: Group by Participant ID
# - Step 2: Sort timestamp from earliest to lowest
# - Step 3: Remove duplicate adjascent lines with no change in other features except for the time stamp
# - Step 4: Combine all participant data together

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from preprocessing import *

# %%
# id_path = r"C:\Users\ASUS\Desktop\MSc\MSBD 5005\MSBD5005_DataVizProject\participantIds.csv"
id_path = r"D:\GitHub\MSBD5005_DataVizProject\participantIds.csv"
preProcessDf.processDataofParticipants(id_path)
# Out:
# ------------Reading ParticipantStatusLogs1------------
# ------------Reading ParticipantStatusLogs2------------
# ------------Reading ParticipantStatusLogs3------------
# ------------Reading ParticipantStatusLogs4------------
# ------------Reading ParticipantStatusLogs5------------
# ------------Reading ParticipantStatusLogs6------------
# ------------Reading ParticipantStatusLogs7------------
# ------------Reading ParticipantStatusLogs8------------
# ------------Reading ParticipantStatusLogs9------------
# ------------Reading ParticipantStatusLogs10------------
# ------------Reading ParticipantStatusLogs11------------
# ------------Reading ParticipantStatusLogs12------------
# ------------Reading ParticipantStatusLogs13------------
# ------------Reading ParticipantStatusLogs14------------
# ------------Reading ParticipantStatusLogs15------------
# ------------Reading ParticipantStatusLogs16------------
# ------------Reading ParticipantStatusLogs17------------
# ...

# %%
list(pd.read_csv(id_path)['participantId'].astype(int))
# Out:
# [901,
#  902,
#  903,
#  904,
#  905,
#  906,
#  907,
#  908,
#  909,
#  910,
#  911,
#  912,
#  913,
#  914,
#  915,
#  916,
#  917,
#  918,
#  919,
#  920,
#  921,
#  922,
#  923,
#  924,
#  925,
#  926,
#  927,
#  928,
#  929,
#  930,
#  931,
#  932,
#  933,
#  934,
#  935,
#  936,
#  937,
#  938,
#  939,
#  940,
#  941,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  948,
#  949,
#  950,
#  951,
#  952,
#  953,
#  954,
#  955,
#  956,
#  957,
#  958,
#  959,
#  960,
#  961,
#  962,
#  963,
#  964,
#  965,
#  966,
#  967,
#  968,
#  969,
#  970,
#  971,
#  972,
#  973,
#  974,
#  975,
#  976,
#  977,
#  978,
#  979,
#  980,
#  981,
#  982,
#  983,
#  984,
#  985,
#  986,
#  987,
#  988,
#  989,
#  990,
#  991,
#  992,
#  993,
#  994,
#  995,
#  996,
#  997,
#  998,
#  999,
#  1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  1010]

# %%
pd.read_csv(id_path)['participantId']
# Out:
# 0      700
# 1      701
# 2      702
# 3      703
# 4      704
#       ...
# 196    896
# 197    897
# 198    898
# 199    899
# 200    900
# Name: participantId, Length: 201, dtype: int64
