# %% [markdown]
# This notebook intends to reduce the size of the activity logs.
#
# As the activity log polls every 5 minutes regardless of whether there has been any movement, we can get rid of timestamps which give no useful information.
#
# - Step 1: Group by Participant ID
# - Step 2: Sort timestamp from earliest to lowest
# - Step 3: Remove duplicate adjascent lines with no change in other features except for the time stamp
# - Step 4: Combine all participant data together

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from preprocessing import *

# %%
# id_path = r"C:\Users\ASUS\Desktop\MSc\MSBD 5005\MSBD5005_DataVizProject\participantIds.csv"
id_path = r"D:\GitHub\MSBD5005_DataVizProject\participantIds.csv"
preProcessDf.processDataofParticipants(id_path)
# Out:
# ------------Reading ParticipantStatusLogs1------------
# ------------Reading ParticipantStatusLogs2------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36872\3541376541.py in <module>
#       1 # id_path = r"C:\Users\ASUS\Desktop\MSc\MSBD 5005\MSBD5005_DataVizProject\participantIds.csv"
#       2 id_path = r"D:\GitHub\MSBD5005_DataVizProject\participantIds.csv"
# ----> 3 preProcessDf.processDataofParticipants(id_path)
#
# d:\GitHub\MSBD5005_DataVizProject\preprocessing\preProcessDf.py in processDataofParticipants(id_path)
#     124 def processDataofParticipants(id_path):
#     125     ids = list(pd.read_csv(id_path)[participantIDColName].astype(int))
# --> 126     full_data = readActivityLogs()
#     127     for id in ids:
#     128         print(f"-------Doing Participant {id}------")
#
# d:\GitHub\MSBD5005_DataVizProject\preprocessing\preProcessDf.py in readActivityLogs()
#      77         print(f"------------Reading {FILE_SUFFIX}{i}------------")
#      78         filepath = f'{MAIN_ACTIVITY_PATH}/{FILE_SUFFIX}{i}.csv'
# ---> 79         df = pd.read_csv(filepath)
#      80         tmp.append(df)
#      81         # print(f"--------Done Reading {FILE_SUFFIX}{i}------------")
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067             new_rows = len(index)
#    1068
# -> 1069         df = DataFrame(col_dict, columns=columns, index=index)
#    1070
#    1071         self._currow += new_rows
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1699     arrays = [x if not isinstance(x, ABCPandasArray) else x.to_numpy() for x in arrays]
#    1700     try:
# -> 1701         blocks = _form_blocks(arrays, names, axes)
#    1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in _form_blocks(arrays, names, axes)
#    1788
#    1789     if len(items_dict["ObjectBlock"]) > 0:
# -> 1790         object_blocks = _simple_blockify(items_dict["ObjectBlock"], np.object_)
#    1791         blocks.extend(object_blocks)
#    1792
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in _simple_blockify(tuples, dtype)
#    1832     not None, coerce to this dtype
#    1833     """
# -> 1834     values, placement = _stack_arrays(tuples, dtype)
#    1835
#    1836     # TODO: CHECK DTYPE?
#
# c:\Users\TANGGA\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1880     stacked = np.empty(shape, dtype=dtype)
#    1881     for i, arr in enumerate(arrays):
# -> 1882         stacked[i] = _asarray_compat(arr)
#    1883
#    1884     return stacked, placement
#
# KeyboardInterrupt:

# %%
list(pd.read_csv(id_path)['participantId'].astype(int))
# Out:
# [700,
#  701,
#  702,
#  703,
#  704,
#  705,
#  706,
#  707,
#  708,
#  709,
#  710,
#  711,
#  712,
#  713,
#  714,
#  715,
#  716,
#  717,
#  718,
#  719,
#  720,
#  721,
#  722,
#  723,
#  724,
#  725,
#  726,
#  727,
#  728,
#  729,
#  730,
#  731,
#  732,
#  733,
#  734,
#  735,
#  736,
#  737,
#  738,
#  739,
#  740,
#  741,
#  742,
#  743,
#  744,
#  745,
#  746,
#  747,
#  748,
#  749,
#  750,
#  751,
#  752,
#  753,
#  754,
#  755,
#  756,
#  757,
#  758,
#  759,
#  760,
#  761,
#  762,
#  763,
#  764,
#  765,
#  766,
#  767,
#  768,
#  769,
#  770,
#  771,
#  772,
#  773,
#  774,
#  775,
#  776,
#  777,
#  778,
#  779,
#  780,
#  781,
#  782,
#  783,
#  784,
#  785,
#  786,
#  787,
#  788,
#  789,
#  790,
#  791,
#  792,
#  793,
#  794,
#  795,
#  796,
#  797,
#  798,
#  799,
#  800,
#  801,
#  802,
#  803,
#  804,
#  805,
#  806,
#  807,
#  808,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  815,
#  816,
#  817,
#  818,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  829,
#  830,
#  831,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  839,
#  840,
#  841,
#  842,
#  843,
#  844,
#  845,
#  846,
#  847,
#  848,
#  849,
#  850,
#  851,
#  852,
#  853,
#  854,
#  855,
#  856,
#  857,
#  858,
#  859,
#  860,
#  861,
#  862,
#  863,
#  864,
#  865,
#  866,
#  867,
#  868,
#  869,
#  870,
#  871,
#  872,
#  873,
#  874,
#  875,
#  876,
#  877,
#  878,
#  879,
#  880,
#  881,
#  882,
#  883,
#  884,
#  885,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  892,
#  893,
#  894,
#  895,
#  896,
#  897,
#  898,
#  899,
#  900]

# %%
pd.read_csv(id_path)['participantId']
# Out:
# 0      700
# 1      701
# 2      702
# 3      703
# 4      704
#       ...
# 196    896
# 197    897
# 198    898
# 199    899
# 200    900
# Name: participantId, Length: 201, dtype: int64
