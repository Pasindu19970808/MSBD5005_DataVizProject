# %%
'https://www.kaggle.com/code/dhruvildave/d3-js-jupyter'

from string import Template
from pathlib import Path

import IPython.display as dp
import pandas as pd

# %%
file_path = r'data\VAST-Challenge-2022\Datasets\Attributes'
df = pd.read_csv(Path(Path(file_path,'Participants.csv')))

# %%
df
# Out:
#       participantId  householdSize  haveKids  age       educationLevel
# 0                 0              3      True   36  HighSchoolOrCollege  \
# 1                 1              3      True   25  HighSchoolOrCollege
# 2                 2              3      True   35  HighSchoolOrCollege
# 3                 3              3      True   21  HighSchoolOrCollege
# 4                 4              3      True   43            Bachelors
# ...             ...            ...       ...  ...                  ...
# 1006           1006              1     False   19  HighSchoolOrCollege
# 1007           1007              1     False   40  HighSchoolOrCollege
# 1008           1008              1     False   23             Graduate
# 1009           1009              1     False   39                  Low
# 1010           1010              1     False   52  HighSchoolOrCollege
#
#      interestGroup  joviality
# 0                H   0.001627
# 1                B   0.328087
# 2                A   0.393470
# 3                I   0.138063
# 4                H   0.857397
# ...            ...        ...
# 1006             J   0.639268
# 1007             B   0.934348
# 1008             C   0.163721
# 1009             B   0.828330
# 1010             D   0.175388
#
# [1011 rows x 7 columns]

# %%
s = Template(
    r"""
<style>
  @import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&family=IBM+Plex+Sans&display=swap');

  *,
  *::before,
  *::after {
    box-sizing: border-box;
    margin: 0;
    padding: 0;
  }

  #$id {
    text-align: center;
  }

  #$id .axis.x line {
    display: none;
  }

  #$id .axis text {
    font-weight: bold;
    font-family: 'IBM Plex Mono', monospace;
    text-transform: capitalize;
  }
</style>

<div id="$id"></div>

<script type="module">
  'use strict';
  import * as d3 from 'https://cdn.skypack.dev/d3';
  (async () => {
    const data = d3.csvParse(`$df`, d3.autoType);

    const margin = { top: 40, right: 40, bottom: 40, left: 40 };
    const [w, h] = [500, 500];

    const svg = d3
      .select('#$id')
      .append('svg')
      .attr('width', w)
      .attr('height', h);

    const g = d3.flatRollup(
      data,
      v => d3.mean(v, d => d['joviality']),
      d => d['haveKids']
    );

    const xScale = d3.scaleBand(
      g.map(i => i[0]),
      [margin.left, w - margin.right]
    );
    const yMax = Math.ceil(d3.max(g, i => i[1]) / 10) ;
    const yScale = d3.scaleLinear([0, yMax], [h - margin.bottom, margin.top]);

    svg
      .append('g')
      .attr('class', 'axis x')
      .attr('transform', `translate(0, ${h - margin.top})`)
      .call(d3.axisBottom(xScale));
    svg
      .append('g')
      .attr('class', 'axis y')
      .attr('transform', `translate(${margin.left}, 0)`)
      .call(d3.axisLeft(yScale).ticks(7));

    const barWidth = 80;
    svg
      .selectAll('rect')
      .data(g)
      .enter()
      .append('rect')
      .attr('width', barWidth)
      .attr('height', d => h - margin.top - yScale(d[1]))
      .attr('x', d => xScale(d[0]) + xScale.bandwidth() / 2 - barWidth / 2)
      .attr('y', d => yScale(d[1]))
      .attr('fill', '#3182bd')
      .exit()
      .remove();
    svg
      .selectAll('rect')
      .on('mouseenter', function () {
        d3.select(this).transition().duration(300).attr('fill', '#08519c');
      })
      .on('mouseleave', function () {
        d3.select(this).transition().duration(300).attr('fill', '#3182bd');
      });

    svg
      .append('text')
      .text('Average `joviality` grouped by `havekids`')
      .style('font-family', 'IBM Plex Sans')
      .style('font-weight', 'bold')
      .style('font-size', '1.5rem')
      .attr('x', margin.left / 2)
      .attr('y', margin.top / 2);
    svg
      .append('text')
      .text('havekids')
      .style('font-family', 'IBM Plex Sans')
      .style('font-weight', 'bold')
      .style('font-size', '1.2rem')
      .style('text-anchor', 'middle')
      .attr('x', w / 2)
      .attr('y', h);
    svg
      .append('text')
      .text('joviality')
      .style('font-family', 'IBM Plex Sans')
      .style('font-weight', 'bold')
      .style('font-size', '1.2rem')
      .style('text-anchor', 'middle')
      .attr('x', margin.left / 2 - 5)
      .attr('transform', `rotate(-90, ${margin.left / 2 - 5}, ${h / 2})`)
      .attr('y', h / 2);
  })();
</script>
    """
)

dp.HTML(s.safe_substitute({"df": df.to_csv(index=False), "id": "g0"}))
# Out:
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&family=IBM+Plex+Sans&display=swap');
#
#   *,
#   *::before,
#   *::after {
#     box-sizing: border-box;
#     margin: 0;
#     padding: 0;
#   }
#
#   #g0 {
#     text-align: center;
#   }
#
#   #g0 .axis.x line {
#     display: none;
#   }
#
#   #g0 .axis text {
#     font-weight: bold;
#     font-family: 'IBM Plex Mono', monospace;
#     text-transform: capitalize;
#   }
# </style>
#
# <div id="g0"></div>
#
# <script type="module">
#   'use strict';
#   import * as d3 from 'https://cdn.skypack.dev/d3';
#   (async () => {
#     const data = d3.csvParse(`participantId,householdSize,haveKids,age,educationLevel,interestGroup,joviality
# 0,3,True,36,HighSchoolOrCollege,H,0.001626703
# 1,3,True,25,HighSchoolOrCollege,B,0.3280865
# 2,3,True,35,HighSchoolOrCollege,A,0.39346959
# 3,3,True,21,HighSchoolOrCollege,I,0.138063446
# 4,3,True,43,Bachelors,H,0.857396691
# 5,3,True,32,HighSchoolOrCollege,D,0.772957791
# 6,3,True,26,HighSchoolOrCollege,I,0.833980668
# 7,3,True,27,Bachelors,A,0.958189409
# 8,3,True,20,Bachelors,G,0.697554819
# 9,3,True,35,Bachelors,D,0.467131409
# 10,3,True,48,HighSchoolOrCollege,D,0.557176006
# 11,3,True,27,HighSchoolOrCollege,F,0.25422732
# 12,3,True,34,HighSchoolOrCollege,D,0.241615182
# 13,3,True,18,Bachelors,J,0.724503834
# 14,3,True,38,Graduate,H,0.930003289
# 15,3,True,35,HighSchoolOrCollege,I,0.232266068
# 16,3,True,39,Bachelors,J,0.392189088
# 17,3,True,57,Bachelors,I,0.114667399
# 18,3,True,20,Graduate,I,0.32696558
# 19,3,True,25,Bachelors,B,0.486470164
# 20,3,True,41,HighSchoolOrCollege,I,0.619057739
# 21,3,True,35,Low,E,0.931240975
# 22,3,True,25,HighSchoolOrCollege,E,0.663815663
# 23,3,True,57,Low,B,0.260211811
# 24,3,True,44,Bachelors,D,0.607328128
# 25,3,True,38,HighSchoolOrCollege,J,0.520535752
# 26,3,True,28,HighSchoolOrCollege,F,0.549177225
# 27,3,True,45,HighSchoolOrCollege,D,0.135148815
# 28,3,True,54,Bachelors,A,0.230073813
# 29,3,True,18,Low,C,0.607853294
# 30,3,True,49,HighSchoolOrCollege,C,0.681423545
# 31,3,True,40,Graduate,F,0.23266675
# 32,3,True,33,HighSchoolOrCollege,C,0.189498641
# 33,3,True,21,Bachelors,D,0.094585958
# 34,3,True,23,Low,B,0.767112453
# 35,3,True,20,Low,J,0.707950782
# 36,3,True,41,Graduate,G,0.348019484
# 37,3,True,54,HighSchoolOrCollege,G,0.174975799
# 38,3,True,34,Low,D,0.215116214
# 39,3,True,54,Bachelors,G,0.862950926
# 40,3,True,55,Low,I,0.880410054
# 41,3,True,41,HighSchoolOrCollege,F,0.863663966
# 42,3,True,24,HighSchoolOrCollege,J,0.055283617
# 43,3,True,48,Bachelors,E,0.045228735
# 44,3,True,39,Low,C,0.976499153
# 45,3,True,50,Graduate,E,0.179657824
# 46,3,True,47,HighSchoolOrCollege,D,0.225049088
# 47,3,True,58,HighSchoolOrCollege,C,0.424159724
# 48,3,True,42,HighSchoolOrCollege,F,0.485827661
# 49,3,True,54,Graduate,D,0.229589642
# 50,3,True,45,HighSchoolOrCollege,H,0.576174771
# 51,3,True,26,Graduate,G,0.374354513
# 52,3,True,39,HighSchoolOrCollege,B,0.730126771
# 53,3,True,19,Low,H,0.140697641
# 54,3,True,32,Graduate,I,0.778504463
# 55,3,True,37,HighSchoolOrCollege,J,0.770806686
# 56,3,True,40,Graduate,G,0.734056857
# 57,3,True,56,Graduate,A,0.422849796
# 58,3,True,40,Graduate,J,0.192945633
# 59,3,True,35,Bachelors,C,0.186308253
# 60,3,True,46,HighSchoolOrCollege,D,0.411129251
# 61,3,True,44,HighSchoolOrCollege,F,0.598278749
# 62,3,True,57,Bachelors,A,0.491406814
# 63,3,True,36,HighSchoolOrCollege,G,0.583943591
# 64,3,True,52,HighSchoolOrCollege,I,0.330606159
# 65,3,True,23,HighSchoolOrCollege,I,0.498178653
# 66,3,True,51,Bachelors,J,0.773765426
# 67,3,True,19,HighSchoolOrCollege,C,0.438788793
# 68,3,True,42,HighSchoolOrCollege,G,0.519538618
# 69,3,True,24,Bachelors,B,0.743901318
# 70,3,True,49,HighSchoolOrCollege,D,0.72544679
# 71,3,True,59,Bachelors,J,0.947066909
# 72,3,True,21,Bachelors,B,0.218744284
# 73,3,True,32,Bachelors,H,0.381370977
# 74,3,True,48,HighSchoolOrCollege,B,0.904601349
# 75,2,False,59,HighSchoolOrCollege,A,0.791342831
# 76,2,False,34,HighSchoolOrCollege,I,0.362917704
# 77,2,False,20,HighSchoolOrCollege,C,0.621716267
# 78,2,False,24,Graduate,B,0.188638917
# 79,2,False,56,HighSchoolOrCollege,C,0.03403389
# 80,2,False,59,HighSchoolOrCollege,E,0.40138993
# 81,2,False,27,Graduate,D,0.871320255
# 82,2,False,40,Graduate,H,0.955760648
# 83,2,False,53,HighSchoolOrCollege,C,0.027148207
# 84,2,False,33,HighSchoolOrCollege,J,0.455102277
# 85,2,False,45,HighSchoolOrCollege,A,0.354510651
# 86,2,False,31,HighSchoolOrCollege,C,0.399201318
# 87,2,False,58,HighSchoolOrCollege,A,0.725176476
# 88,2,False,20,HighSchoolOrCollege,A,0.746921002
# 89,2,False,54,HighSchoolOrCollege,J,0.169054036
# 90,2,False,20,HighSchoolOrCollege,E,0.139818869
# 91,2,False,41,HighSchoolOrCollege,E,0.733204092
# 92,2,False,43,HighSchoolOrCollege,J,0.467868166
# 93,2,False,48,HighSchoolOrCollege,B,0.580101654
# 94,2,False,23,Bachelors,C,0.413830119
# 95,2,False,47,Low,H,0.451218504
# 96,2,False,23,HighSchoolOrCollege,B,0.504845427
# 97,2,False,56,Graduate,J,0.679506778
# 98,2,False,55,HighSchoolOrCollege,B,0.366630644
# 99,2,False,31,Bachelors,H,0.39686665
# 100,2,False,29,Low,F,0.142686163
# 101,2,False,38,HighSchoolOrCollege,A,0.020504586
# 102,2,False,56,Bachelors,A,0.265501227
# 103,2,False,18,Bachelors,J,0.194724115
# 104,2,False,47,HighSchoolOrCollege,F,0.991414933
# 105,2,False,52,HighSchoolOrCollege,J,0.851915894
# 106,2,False,34,Bachelors,A,0.700811306
# 107,2,False,26,HighSchoolOrCollege,C,0.357131296
# 108,2,False,36,HighSchoolOrCollege,C,0.098903572
# 109,2,False,52,HighSchoolOrCollege,C,0.290464519
# 110,2,False,26,HighSchoolOrCollege,D,0.313305546
# 111,2,False,30,HighSchoolOrCollege,B,0.720330648
# 112,2,False,23,Graduate,C,0.646977694
# 113,2,False,51,Graduate,G,0.999233967
# 114,2,False,55,Graduate,G,0.413490065
# 115,2,False,56,HighSchoolOrCollege,J,0.57753282
# 116,2,False,43,Graduate,E,0.30282788
# 117,2,False,22,Bachelors,F,0.760663448
# 118,2,False,33,Bachelors,C,0.140611532
# 119,2,False,32,Graduate,B,0.612907872
# 120,2,False,31,HighSchoolOrCollege,E,0.876546337
# 121,2,False,45,HighSchoolOrCollege,F,0.41537229
# 122,2,False,37,HighSchoolOrCollege,A,0.159723746
# 123,2,False,43,HighSchoolOrCollege,B,0.118152103
# 124,2,False,49,Graduate,I,0.14336634
# 125,2,False,50,Graduate,E,0.150075471
# 126,2,False,26,HighSchoolOrCollege,A,0.72895287
# 127,2,False,60,HighSchoolOrCollege,E,0.882038681
# 128,2,False,57,Bachelors,G,0.718790546
# 129,2,False,27,HighSchoolOrCollege,B,0.371183768
# 130,2,False,48,HighSchoolOrCollege,J,0.524660325
# 131,2,False,26,Bachelors,H,0.802929522
# 132,2,False,36,Graduate,I,0.540291283
# 133,2,False,27,HighSchoolOrCollege,I,0.551268581
# 134,2,False,53,HighSchoolOrCollege,D,0.247000174
# 135,2,False,59,HighSchoolOrCollege,E,0.86081073
# 136,2,False,34,Graduate,A,0.555650922
# 137,2,False,34,HighSchoolOrCollege,C,0.87301128
# 138,2,False,49,HighSchoolOrCollege,H,0.732757238
# 139,2,False,48,Bachelors,C,0.846097713
# 140,2,False,24,Bachelors,I,0.216307476
# 141,2,False,24,Bachelors,B,0.792161061
# 142,2,False,24,HighSchoolOrCollege,F,0.789243454
# 143,2,False,18,HighSchoolOrCollege,A,0.107753878
# 144,2,False,23,HighSchoolOrCollege,I,0.444080663
# 145,2,False,30,HighSchoolOrCollege,F,0.882253016
# 146,2,False,46,HighSchoolOrCollege,J,0.643761923
# 147,2,False,44,HighSchoolOrCollege,J,0.528698226
# 148,2,False,37,Bachelors,A,0.266938991
# 149,2,False,26,Bachelors,A,0.80654106
# 150,2,False,44,Bachelors,H,0.20807405
# 151,2,False,46,Low,G,0.159854965
# 152,2,False,41,HighSchoolOrCollege,I,0.6089739
# 153,2,False,23,HighSchoolOrCollege,A,0.758079342
# 154,2,False,29,HighSchoolOrCollege,J,0.954706293
# 155,2,False,55,Graduate,A,0.176618296
# 156,2,False,52,HighSchoolOrCollege,J,0.466716971
# 157,2,False,25,Graduate,J,0.254005742
# 158,2,False,25,Graduate,J,0.468930899
# 159,2,False,39,HighSchoolOrCollege,G,0.24297235
# 160,2,False,52,Bachelors,F,0.168095803
# 161,2,False,47,HighSchoolOrCollege,A,0.965708743
# 162,2,False,36,HighSchoolOrCollege,B,0.936659644
# 163,2,False,26,HighSchoolOrCollege,D,0.225309113
# 164,2,False,27,Graduate,F,0.812453062
# 165,2,False,30,Graduate,G,0.964990249
# 166,2,False,21,Low,A,0.627739055
# 167,2,False,49,HighSchoolOrCollege,F,0.846680285
# 168,1,False,48,Graduate,G,0.365595636
# 169,1,False,24,HighSchoolOrCollege,J,0.364391587
# 170,1,False,20,Bachelors,G,0.133248852
# 171,1,False,58,Low,I,0.114389766
# 172,1,False,38,Graduate,I,0.575001936
